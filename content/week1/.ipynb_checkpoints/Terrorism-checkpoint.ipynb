# %%
import pandas as pd

# %%
#df = pd.read_excel("data/terrorism.xls")
df = pd.read_excel("http://nodepro.hackcville.com/week1/data/terrorism.csv")

# %%
df
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaT
# 1      197000000002   1970       0     0        NaN         0        NaT
# 2      197001000001   1970       1     0        NaN         0        NaT
# 3      197001000002   1970       1     0        NaN         0        NaT
# 4      197001000003   1970       1     0        NaN         0        NaT
# ...             ...    ...     ...   ...        ...       ...        ...
# 65530  199706050001   1997       6     5        NaN         0        NaT
# 65531  199706050003   1997       6     5        NaN         0        NaT
# 65532  199706050004   1997       6     5        NaN         0        NaT
# 65533  199706050005   1997       6     5        NaN         0        NaT
# 65534  199706050006   1997       6     5        NaN         0        NaT
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# ...

# %%
list(df.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
colsIwant = ["iyear","imonth","iday", "country_txt","attacktype1_txt","suicide","targtype1_txt"]

# %%
df = df[colsIwant]

# %%
df[df.iyear== 1970]
# Out:
#      iyear  imonth  iday         country_txt                 attacktype1_txt  \
# 0     1970       7     2  Dominican Republic                   Assassination
# 1     1970       0     0              Mexico     Hostage Taking (Kidnapping)
# 2     1970       1     0         Philippines                   Assassination
# 3     1970       1     0              Greece               Bombing/Explosion
# 4     1970       1     0               Japan  Facility/Infrastructure Attack
# ..     ...     ...   ...                 ...                             ...
# 646   1970      12    29              Turkey                   Armed Assault
# 647   1970      12    29           Argentina                   Armed Assault
# 648   1970      12    30               Spain               Bombing/Explosion
# 649   1970      12    31  West Germany (FRG)                   Armed Assault
# 650   1970      12    31       United States               Bombing/Explosion
#
#      suicide                targtype1_txt
# ...

# %%
df[df.country_txt == "United States"]
# Out:
#        iyear  imonth  iday    country_txt                 attacktype1_txt  \
# 5       1970       1     1  United States                   Armed Assault
# 7       1970       1     2  United States               Bombing/Explosion
# 8       1970       1     2  United States  Facility/Infrastructure Attack
# 9       1970       1     3  United States  Facility/Infrastructure Attack
# 10      1970       1     1  United States               Bombing/Explosion
# ...      ...     ...   ...            ...                             ...
# 65320   1997       5     3  United States  Facility/Infrastructure Attack
# 65335   1997       5     6  United States  Facility/Infrastructure Attack
# 65336   1997       5     6  United States  Facility/Infrastructure Attack
# 65429   1997       5    23  United States  Facility/Infrastructure Attack
# 65468   1997       5    29  United States               Bombing/Explosion
#
#        suicide         targtype1_txt
# 5            0                Police
# ...

# %%
sub1 = df[df.country_txt == "United States"]
sub1[sub1.iyear== 1970]
# Out:
#      iyear  imonth  iday    country_txt                 attacktype1_txt  \
# 5     1970       1     1  United States                   Armed Assault
# 7     1970       1     2  United States               Bombing/Explosion
# 8     1970       1     2  United States  Facility/Infrastructure Attack
# 9     1970       1     3  United States  Facility/Infrastructure Attack
# 10    1970       1     1  United States               Bombing/Explosion
# ..     ...     ...   ...            ...                             ...
# 639   1970      12    16  United States  Facility/Infrastructure Attack
# 641   1970      12    18  United States               Bombing/Explosion
# 642   1970      12    22  United States               Bombing/Explosion
# 645   1970      12    27  United States               Bombing/Explosion
# 650   1970      12    31  United States               Bombing/Explosion
#
#      suicide         targtype1_txt
# 5          0                Police
# ...

# %%
df["attacktype1_txt"].value_counts()
# Out:
# Bombing/Explosion                      27595
# Armed Assault                          15066
# Assassination                          12002
# Facility/Infrastructure Attack          4428
# Hostage Taking (Kidnapping)             2773
# Unknown                                 2383
# Hostage Taking (Barricade Incident)      620
# Unarmed Assault                          341
# Hijacking                                327
# Name: attacktype1_txt, dtype: int64

# %%
df.suicide.value_counts(normalize= True)
# Out:
# 0    0.998535
# 1    0.001465
# Name: suicide, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))

sns.countplot(x= "attacktype1_txt",data=df)

# %% [markdown]
# # Questions to Answer with Your Table

# %% [markdown]
# 1. What is the most frequent type of attack in the United States?
# 2. Who is targetted the most in Japan?
# 3. How many Bombing/Explosions are there in 1974?
