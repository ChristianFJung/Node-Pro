# %%
client_id = "60be6aa7418242fcb805ac8957238ef3"
client_secret = "b8e6ccf530934030b1ee65af15121fee"

# %%
# !pip install spotipy

# %%
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
client_id= "eed7f8fb1694466596d934b6e16a65d2"
client_secret= "f7f3ac9a24724267a982392529361d07"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 spotify:playlist:37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 spotify:playlist:37i9dQZF1DX1lVhptIYRda Hot Country
#    4 spotify:playlist:37i9dQZF1DX10zKzsJ2jva ¡Viva Latino!
#    5 spotify:playlist:37i9dQZF1DX4JAvHpjipBk New Music Friday
#    6 spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n mint
#    7 spotify:playlist:37i9dQZF1DX4SBhb3fqCJd Are & Be
#    8 spotify:playlist:37i9dQZF1DWXRqgorJj26U Rock Classics
#    9 spotify:playlist:37i9dQZF1DX4sWSpwq3LiO Peaceful Piano
#   10 spotify:playlist:37i9dQZF1DXcF6B6QPhFDv Rock This
#   11 spotify:playlist:37i9dQZF1DWXJfnUiYjUKT New Music Friday
#   12 spotify:playlist:37i9dQZF1DXcRXFNfZr7Tp just hits
#   13 spotify:playlist:37i9dQZF1DX4o1oenSJRJd All Out 00s
#   14 spotify:playlist:37i9dQZF1DXbTxeAdrVG2l All Out 90s
#   15 spotify:playlist:37i9dQZF1DX4UtSsGT1Sbe All Out 80s
#   16 spotify:playlist:37i9dQZF1DWTJ7xPn4vNaz All Out 70s
# ...

# %%
sp.search("Kanye West")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Kanye+West&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
# ...

# %%
results = sp.search(q='artist:' + "Kanye West", type='artist')
kanye_id = results["artists"]["items"][0]["id"]

# %%
album_ids= []

for val in sp.artist_albums(kanye_id)["items"]:
    album_ids.append(val["id"])
    
album_ids
# Out:
# ['0FgZKfoU2Br5sHOfvZKTI9',
#  '6pwuKxMUkNg673KETsXPUV',
#  '2Ek1q2haOnxVqhvVKqMvJe',
#  '7gsWAHLeT0w7es6FofOXk1',
#  '7u6Q36bDPiNegcQ7u69bKq',
#  '7D2NdGvBHIavgLhmcwhluK',
#  '0A3g19AGFd9Qe3rAIkP8e0',
#  '2P2Xwvh2xWXIZ1OWY9S9o5',
#  '1YwzJz7CrV9fd9Qeb6oo1d',
#  '4P63UgNDUcF11MnWzyvVrh',
#  '2IC7s3KVP6ottxQUnkm4eS',
#  '7mCeLbChyegbRwwKK5shJs',
#  '0OcMap99vLEeGkBCfCwRwS',
#  '0eZRIt3Ht1IuMXsr0QR8OY',
#  '6Oa0ZYzr4VdFIz3zNmYJYQ',
#  '20r762YmB5HeofjMCiPMLv',
#  '6klUp8sQyRXGuJhqZu4PG3',
#  '3WFTGIO6E3Xh4paEOBY9OU',
#  '5ykOQlHaE5ZRxMibfI75YW',
#  '4SZko61aMnmgvNhfhgTuD3']

# %%
album_one= album_ids[0]
sp.album_tracks(album_one)
# Out:
# {'href': 'https://api.spotify.com/v1/albums/0FgZKfoU2Br5sHOfvZKTI9/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#      'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#      'id': '5K4W6rqBFWDnAN6FQUkS6x',
#      'name': 'Kanye West',
#      'type': 'artist',
#      'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c9O21YLFy4tFI9zCVhbFg'},
#      'href': 'https://api.spotify.com/v1/artists/2c9O21YLFy4tFI9zCVhbFg',
#      'id': '2c9O21YLFy4tFI9zCVhbFg',
#      'name': 'Sunday Service Choir',
#      'type': 'artist',
#      'uri': 'spotify:artist:2c9O21YLFy4tFI9zCVhbFg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
# ...

# %%
sp.album_tracks(album_one)["items"][0]["name"]
# Out:
# 'Every Hour'

# %%
song_ids =[]
song_names= []
for val in sp.album_tracks(album_one)["items"]:
    
    song_ids.append(val["id"])
    song_names.append(val["name"])

song_names
# Out:
# ['Every Hour',
#  'Selah',
#  'Follow God',
#  'Closed On Sunday',
#  'On God',
#  'Everything We Need',
#  'Water',
#  'God Is',
#  'Hands On',
#  'Use This Gospel',
#  'Jesus Is Lord']

# %%
song_ids =[]
song_names= []


for album in album_ids:
    for val in sp.album_tracks(album)["items"]:
        song_ids.append(val["id"])
        song_names.append(val["name"])

song_names
# Out:
# ['Every Hour',
#  'Selah',
#  'Follow God',
#  'Closed On Sunday',
#  'On God',
#  'Everything We Need',
#  'Water',
#  'God Is',
#  'Hands On',
#  'Use This Gospel',
#  'Jesus Is Lord',
#  'Feel The Love',
#  'Fire',
#  '4th Dimension',
#  'Freeee (Ghost Town Pt. 2)',
#  'Reborn',
#  'Kids See Ghosts',
#  'Cudi Montage',
#  'I Thought About Killing You',
#  'Yikes',
#  'All Mine',
#  "Wouldn't Leave",
#  'No Mistakes',
#  'Ghost Town',
#  'Violent Crimes',
#  'Ultralight Beam',
#  'Father Stretch My Hands Pt. 1',
#  'Pt. 2',
#  'Famous',
#  'Feedback',
#  'Low Lights',
#  'Highlights',
#  'Freestyle 4',
#  'I Love Kanye',
#  'Waves',
#  'FML',
#  'Real Friends',
#  'Wolves',
#  "Frank's Track",
#  'Siiiiiiiiilver Surffffeeeeer Intermission',
#  '30 Hours',
#  'No More Parties In LA',
#  'Facts (Charlie Heat Version)',
#  'Fade',
#  'Saint Pablo',
#  'Ultralight Beam',
#  'Father Stretch My Hands Pt. 1',
#  'Pt. 2',
#  'Famous',
#  'Feedback',
#  'Low Lights',
#  'Highlights',
# ...

# %%
len(song_ids)
# Out:
# 262

# %%
p1 = sp.audio_features(song_ids[0:100])
p2= sp.audio_features(song_ids[100:200])
p3 = sp.audio_features(song_ids[200:263])
p3
# Out:
# [{'danceability': 0.542,
#   'energy': 0.914,
#   'key': 0,
#   'loudness': -4.747,
#   'mode': 0,
#   'speechiness': 0.113,
#   'acousticness': 0.0161,
#   'instrumentalness': 0,
#   'liveness': 0.744,
#   'valence': 0.576,
#   'tempo': 153.993,
#   'type': 'audio_features',
#   'id': '2gZUPNdnz5Y45eiGxpHGSc',
#   'uri': 'spotify:track:2gZUPNdnz5Y45eiGxpHGSc',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gZUPNdnz5Y45eiGxpHGSc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gZUPNdnz5Y45eiGxpHGSc',
#   'duration_ms': 292093,
#   'time_signature': 4},
#  {'danceability': 0.296,
#   'energy': 0.0792,
#   'key': 10,
#   'loudness': -16.569,
#   'mode': 0,
#   'speechiness': 0.0389,
#   'acousticness': 0.902,
#   'instrumentalness': 0.591,
#   'liveness': 0.128,
#   'valence': 0.496,
#   'tempo': 110.95,
#   'type': 'audio_features',
#   'id': '4D6TpthzUVNTjWQqfBW5Kb',
#   'uri': 'spotify:track:4D6TpthzUVNTjWQqfBW5Kb',
# ...

# %%
p1+p2+p3
# Out:
# [{'danceability': 0.588,
#   'energy': 0.793,
#   'key': 7,
#   'loudness': -6.23,
#   'mode': 1,
#   'speechiness': 0.0794,
#   'acousticness': 0.466,
#   'instrumentalness': 0.000647,
#   'liveness': 0.913,
#   'valence': 0.694,
#   'tempo': 76.997,
#   'type': 'audio_features',
#   'id': '1WnqWQcWcuQbVzgE7ecfCY',
#   'uri': 'spotify:track:1WnqWQcWcuQbVzgE7ecfCY',
#   'track_href': 'https://api.spotify.com/v1/tracks/1WnqWQcWcuQbVzgE7ecfCY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1WnqWQcWcuQbVzgE7ecfCY',
#   'duration_ms': 112239,
#   'time_signature': 5},
#  {'danceability': 0.482,
#   'energy': 0.618,
#   'key': 9,
#   'loudness': -5.673,
#   'mode': 0,
#   'speechiness': 0.197,
#   'acousticness': 0.647,
#   'instrumentalness': 0.000859,
#   'liveness': 0.32,
#   'valence': 0.146,
#   'tempo': 90.076,
#   'type': 'audio_features',
#   'id': '39JRmdKFka1Oe09FoOCPI4',
#   'uri': 'spotify:track:39JRmdKFka1Oe09FoOCPI4',
# ...

# %%
import json
df = pd.DataFrame.from_dict((p1+p2+p3),orient="columns")
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.588   0.793    7    -6.230     1       0.0794      0.466000
# 1           0.482   0.618    9    -5.673     0       0.1970      0.647000
# 2           0.529   0.900    1    -3.503     1       0.4180      0.000248
# 3           0.799   0.291   11    -7.353     0       0.0318      0.873000
# 4           0.410   0.886    9    -4.413     0       0.1550      0.067100
# ..            ...     ...  ...       ...   ...          ...           ...
# 257         0.631   0.623    8    -6.969     1       0.2650      0.463000
# 258         0.423   0.643    6    -7.261     1       0.2870      0.045500
# 259         0.667   0.747    1    -7.059     1       0.1890      0.337000
# 260         0.498   0.742   11    -6.248     0       0.2590      0.214000
# 261         0.696   0.526   11   -10.504     0       0.1710      0.177000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
df["name"]= song_names
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.588   0.793    7    -6.230     1       0.0794      0.466000
# 1           0.482   0.618    9    -5.673     0       0.1970      0.647000
# 2           0.529   0.900    1    -3.503     1       0.4180      0.000248
# 3           0.799   0.291   11    -7.353     0       0.0318      0.873000
# 4           0.410   0.886    9    -4.413     0       0.1550      0.067100
# ..            ...     ...  ...       ...   ...          ...           ...
# 257         0.631   0.623    8    -6.969     1       0.2650      0.463000
# 258         0.423   0.643    6    -7.261     1       0.2870      0.045500
# 259         0.667   0.747    1    -7.059     1       0.1890      0.337000
# 260         0.498   0.742   11    -6.248     0       0.2590      0.214000
# 261         0.696   0.526   11   -10.504     0       0.1710      0.177000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
kanye_album= str(sp.artist_albums(kanye_id))
type(kanye_album)
# Out:
# str

# %%
text_file = open("kanyeAlbums.txt", "w")
n = text_file.write(kanye_album)
text_file.close()

# %%
pd.read_json("kanyeAlbums.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-3a79c96cb888> in <module>
# ----> 1 pd.read_json("kanyeAlbums.txt")
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
#     719         return obj
#
# ...

# %%
sp.artist('5K4W6rqBFWDnAN6FQUkS6x')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#  'followers': {'href': None, 'total': 12341597},
#  'genres': ['chicago rap', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#  'id': '5K4W6rqBFWDnAN6FQUkS6x',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/bd1c6fdf3705cf9b7d0c8ac8e7bbed98e31a1559',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/b1414e865a16bc0080085ee1901d0bfd19f83fcb',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ac5cb571c194ca5a942b8096618217839b901a76',
#    'width': 160}],
#  'name': 'Kanye West',
#  'popularity': 91,
#  'type': 'artist',
#  'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}
